# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\phars\Desktop\data science\data _set-anaysis-projects\regression_loan-prediction\breast-cancer.csv")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.shape
# Out:
# (569, 32)

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
data.drop('id' , axis = 1, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
for var in data.columns:
    print(data[var].value_counts())
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64
# radius_mean
# 12.34    4
# 11.71    3
# 12.46    3
# 13.05    3
# 10.26    3
#         ..
# 12.23    1
# 14.45    1
# 19.18    1
# 18.08    1
# 7.76     1
# Name: count, Length: 456, dtype: int64
# texture_mean
# 20.52    3
# 16.85    3
# 16.84    3
# 19.83    3
# 14.93    3
#         ..
# 18.58    1
# 15.11    1
# 22.41    1
# 14.92    1
# 24.54    1
# Name: count, Length: 479, dtype: int64
# perimeter_mean
# 82.61     3
# 87.76     3
# 134.70    3
# 93.97     2
# 82.69     2
#          ..
# 127.50    1
# 90.63     1
# 82.53     1
# 100.40    1
# 47.92     1
# Name: count, Length: 522, dtype: int64
# area_mean
# 512.2     3
# 1075.0    2
# 582.7     2
# 399.8     2
# 641.2     2
#          ..
# 507.4     1
# 609.9     1
# 463.7     1
# 428.9     1
# 181.0     1
# Name: count, Length: 539, dtype: int64
# smoothness_mean
# 0.10070    5
# 0.11500    4
# 0.10540    4
# 0.10750    4
# 0.10630    3
#           ..
# ...

# %%
#renaming the diagonsis terms

# %%
data['diagnosis'].replace({'M':'malignant', 'B':'benign'},inplace = True)

# %%
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  malignant        17.99         10.38          122.80     1001.0
# 1  malignant        20.57         17.77          132.90     1326.0
# 2  malignant        19.69         21.25          130.00     1203.0
# 3  malignant        11.42         20.38           77.58      386.1
# 4  malignant        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
#checking fo rthe outlier
data.describe().T
# Out:
#                          count        mean         std         min  \
# radius_mean              569.0   14.127292    3.524049    6.981000
# texture_mean             569.0   19.289649    4.301036    9.710000
# perimeter_mean           569.0   91.969033   24.298981   43.790000
# area_mean                569.0  654.889104  351.914129  143.500000
# smoothness_mean          569.0    0.096360    0.014064    0.052630
# compactness_mean         569.0    0.104341    0.052813    0.019380
# concavity_mean           569.0    0.088799    0.079720    0.000000
# concave points_mean      569.0    0.048919    0.038803    0.000000
# symmetry_mean            569.0    0.181162    0.027414    0.106000
# fractal_dimension_mean   569.0    0.062798    0.007060    0.049960
# radius_se                569.0    0.405172    0.277313    0.111500
# texture_se               569.0    1.216853    0.551648    0.360200
# perimeter_se             569.0    2.866059    2.021855    0.757000
# ...

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='diagnosis', data=data , palette='Set2')
plt.title('Distribution of Diagnosis')
plt.xlabel('diagnosis')
plt.ylabel('count')
plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=data , x='radius_mean',hue='diagnosis',palette='Set2',multiple='stack',bins=30)
plt.title('Radius Mean Distribution by Diagnosis')
plt.xlabel('Radius Mean')
plt.ylabel('Count')
plt.grid(axis='y',linestyle='--',alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='texture_mean',hue='diagnosis',palette='Set2',multiple='stack',bins=30)
plt.title('Texture Mean Distribution by diagnosis')
plt.xlabel('Texture Mean')
plt.grid(axis='y',linestyle='--',alpha=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='perimeter_mean',hue='diagnosis',palette='Set3',multiple='stack',bins=30)
plt.title('Distribution of Perimeter Mean by Diagnosis')
plt.xlabel('perimeter_mean',fontsize=12)
plt.ylabel("count",fontsize=12)
plt.grid(axis='y',linestyle='--',alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='area_mean',hue='diagnosis',palette='Set2',multiple='stack',bins=30)
plt.title('Distribution of Area Mean by Diagnosis')
plt.xlabel('Area Mean')
plt.grid(axis='y',linestyle='--',alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='smoothness_mean',hue='diagnosis',palette='Set2',multiple='stack',bins=30)
plt.title('Distribution of  smoothness_mean by Diagnosis')
plt.xlabel('smoothness_mean')
plt.grid(axis='y',linestyle='--',alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=data,x='compactness_worst',y=data.index,hue='diagnosis',palette='Set2')
plt.title('Scatter Plot of Compactness Worst by Diagnosis')
plt.xlabel('compactness_worst')
plt.ylabel('index')
plt.legend(title="Diagnosis")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=data,x='concavity_worst',y=data.index,hue='diagnosis',palette='Set3')
plt.title('Scatter Plot of concavity_worst by Diagnosis')
plt.xlabel('concavity_worst')
plt.ylabel('index')
plt.legend(title="Diagnosis")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=data,x='fractal_dimension_worst',y=data.index,hue='diagnosis',palette='Set1')
plt.title('Scatter Plot of fractal_dimension_worst by Diagnosis')
plt.xlabel('fractal_dimension_worst')
plt.ylabel('index')
plt.legend(title="Diagnosis")
plt.tight_layout()
plt.show()

# %%
data_corr = pd.get_dummies(data, columns=["diagnosis"], dtype=int)
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  malignant        17.99         10.38          122.80     1001.0
# 1  malignant        20.57         17.77          132.90     1326.0
# 2  malignant        19.69         21.25          130.00     1203.0
# 3  malignant        11.42         20.38           77.58      386.1
# 4  malignant        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
corr = data_corr.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr, cmap='rocket',annot=True)
plt.show()

# %%
# Get the highest correlation for Benign
corr_benign = corr["diagnosis_benign"].drop(["diagnosis_benign", "diagnosis_malignant"]).abs()
highest_corr_benign = corr_benign.idxmax()
highest_value_benign = corr_benign.max()

# Get the highest correlation for Malignant
corr_malignant = corr["diagnosis_malignant"].drop(["diagnosis_benign", "diagnosis_malignant"]).abs()
highest_corr_malignant = corr_malignant.idxmax()
highest_value_malignant = corr_malignant.max()

print(f"Highest correlated feature for benign: {highest_corr_benign} ({highest_value_benign:.4f})")
print(f"Highest correlated feature for malignant: {highest_corr_malignant} ({highest_value_malignant:.4f})")
# Out:
# Highest correlated feature for benign: concave points_worst (0.7936)
# Highest correlated feature for malignant: concave points_worst (0.7936)

# %%
print(corr[["diagnosis_benign", "diagnosis_malignant"]].loc[highest_corr_benign])
# Out:
# diagnosis_benign      -0.793566
# diagnosis_malignant    0.793566
# Name: concave points_worst, dtype: float64

# %%
#here our EDA part is done, we implement the EDA for data visulazation we discuss the maligant diagnosis and the benign diagnosis and compare all the attrbute and find the values

# %%
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  malignant        17.99         10.38          122.80     1001.0
# 1  malignant        20.57         17.77          132.90     1326.0
# 2  malignant        19.69         21.25          130.00     1203.0
# 3  malignant        11.42         20.38           77.58      386.1
# 4  malignant        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
x = data.drop("diagnosis", axis=1, inplace=False).values
y = data['diagnosis'].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train.shape , x_test.shape
# Out:
# ((455, 30), (114, 30))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[65  2]
#  [ 2 45]]

# %%
#plot the confusion matri
cm_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(5,4))
sns.heatmap(cm_matrix, cmap="mako", alpha=0.7, annot=True)

# Add labels
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import accuracy_score
ac = accuracy_score(y_test, y_pred)
print(ac)
# Out:
# 0.9649122807017544

# %%
bias = classifier.score(x_train, y_train)
print(bias)
# Out:
# 0.989010989010989

# %%
variance = classifier.score(x_test,y_test)
print(variance)
# Out:
# 0.9649122807017544

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.97      0.97      0.97        67
#    malignant       0.96      0.96      0.96        47
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114
